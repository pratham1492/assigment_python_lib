# %%
# Q1

import pandas as pd

df = pd.read_csv("ipl.csv")

df.head()
# Out:
#             venue_stadium       city        state  capacity home_team
# 0   Narendra Modi Stadium  Ahmedabad       Gujrat    132000        GT
# 1        Wankhede Stadium     Mumbai  Maharashtra     33108        MI
# 2            Eden Gardens    Kolkata  West Bengal     68000       KKR
# 3  MA Chidambaram Stadium    Chennai   Tamil Nadu     50000       CSK
# 4    Arun Jaitley Stadium  New Delhi        Delhi     41000        DC

# %%
# Q2

import pandas as pd

df = pd.read_json("song.json")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        2 non-null      int64
#  1   title     2 non-null      object
#  2   artist    2 non-null      object
#  3   album     2 non-null      object
#  4   duration  2 non-null      object
#  5   src       2 non-null      object
#  6   cover     2 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 244.0+ bytes

# %%
# Q3

# NOT TEACHED

# %%
# Q4

# %%
# Q5

import pandas as pd

df = pd.read_csv("paytm.csv", sep=";")

df.isnull().sum()
# Out:
# Date      0
# Amount    1
# Type      0
# Status    1
# dtype: int64
